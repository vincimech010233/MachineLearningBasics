# %% [markdown]
# <a href="https://colab.research.google.com/github/vincimech010233/MachineLearningBasics/blob/master/Generaci%C3%B3n_de_videos_con_zeroscope_v2_576w.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hola equipo,
#
# Quería compartir con ustedes un recurso interesante que encontré: el modelo "zeroscope_v2_576w" en Hugging Face. Es una herramienta de IA para generar imágenes y videos a partir de descripciones textuales, lo cual puede ser útil para experimentar con visualizaciones en ingeniería.
#
# Pueden echarle un vistazo aquí: https://huggingface.co/cerspense/zeroscope_v2_576w. Creo que podría ser una buena adición a nuestros recursos de IA y ofrece una perspectiva práctica para proyectos creativos.
#
# ¡Espero que lo encuentren tan interesante como yo!

# %%
# !pip install diffusers transformers accelerate torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 68.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 40.2 MB/s eta 0:00:00
# ...

# %%
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video

pipe = DiffusionPipeline.from_pretrained("cerspense/zeroscope_v2_576w", torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

prompt = "Darth Vader is surfing on waves"
video_frames = pipe(prompt, num_inference_steps=40, height=320, width=576, num_frames=24).frames
video_path = export_to_video(video_frames)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# unet/diffusion_pytorch_model.safetensors not found
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
prompt = "construction of a suspension bridge"
video_frames = pipe(prompt, num_inference_steps=40, height=320, width=576, num_frames=24).frames
video_path = "/content/engineering_bridge_construction.mp4"
export_to_video(video_frames, video_path)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# '/content/engineering_bridge_construction.mp4'

# %%
prompt = "gears in motion"
video_frames = pipe(prompt, num_inference_steps=40, height=320, width=576, num_frames=24).frames
video_path = "/content/gears_in_motion.mp4"
export_to_video(video_frames, video_path)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# '/content/gears_in_motion.mp4'

# %%
prompt = "inelastic collision"
video_frames = pipe(prompt, num_inference_steps=40, height=320, width=576, num_frames=24).frames
video_path = "/content/inelastic_collision.mp4"
export_to_video(video_frames, video_path)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# '/content/inelastic_collision.mp4'
