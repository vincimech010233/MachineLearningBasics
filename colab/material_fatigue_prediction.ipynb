# %% [markdown]
# <a href="https://colab.research.google.com/github/vincimech010233/MachineLearningBasics/blob/master/material_fatigue_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Importar las bibliotecas necesarias
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Paso 2: Generar y guardar los datos simulados en un archivo CSV
np.random.seed(0)
n_samples = 1000
density = np.random.uniform(2.5, 7.5, n_samples)
tensile_strength = np.random.uniform(300, 1000, n_samples)
operating_temp = np.random.uniform(-50, 150, n_samples)
cycles_to_failure = np.random.normal(50000, 10000, n_samples)
cycles_to_failure = np.where(cycles_to_failure < 0, 0, cycles_to_failure)

data = pd.DataFrame({
    'Density': density,
    'Tensile_Strength': tensile_strength,
    'Operating_Temp': operating_temp,
    'Cycles_To_Failure': cycles_to_failure
})

csv_file = 'material_fatigue_data.csv'
data.to_csv(csv_file, index=False)

# Paso 3: Cargar y preprocesar los datos
data = pd.read_csv(csv_file)
X = data.drop('Cycles_To_Failure', axis=1)
y = data['Cycles_To_Failure']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

scaler_X = StandardScaler()
scaler_y = MinMaxScaler()  # Escalador para la variable objetivo

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).ravel()
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).ravel()

# Paso 4: Crear y entrenar el modelo de regresión
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train_scaled, y_train_scaled, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Paso 5: Evaluar el modelo
loss = model.evaluate(X_test_scaled, y_test_scaled)
print(f'Pérdida en el conjunto de prueba: {loss}')

# Predicciones (opcional)
predictions = model.predict(X_test_scaled)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 4s 51ms/step - loss: 0.0677 - val_loss: 0.0404
# Epoch 2/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0328 - val_loss: 0.0303
# Epoch 3/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0296 - val_loss: 0.0283
# Epoch 4/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0269 - val_loss: 0.0264
# Epoch 5/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0253 - val_loss: 0.0249
# Epoch 6/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0248 - val_loss: 0.0246
# Epoch 7/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0228 - val_loss: 0.0237
# Epoch 8/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0222 - val_loss: 0.0226
# Epoch 9/100
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0219 - val_loss: 0.0245
# Epoch 10/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0219 - val_loss: 0.0254
# Epoch 11/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0209 - val_loss: 0.0223
# Epoch 12/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0207 - val_loss: 0.0234
# Epoch 13/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0215 - val_loss: 0.0229
# Epoch 14/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0210 - val_loss: 0.0221
# Epoch 15/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0210 - val_loss: 0.0230
# Epoch 16/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0209 - val_loss: 0.0258
# Epoch 17/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0222 - val_loss: 0.0219
# Epoch 18/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0209 - val_loss: 0.0242
# Epoch 19/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0213 - val_loss: 0.0227
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0206 - val_loss: 0.0222
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0204 - val_loss: 0.0244
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0206 - val_loss: 0.0231
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0215 - val_loss: 0.0220
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0205 - val_loss: 0.0235
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0202 - val_loss: 0.0232
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0228
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0234
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0228
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0223
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0207 - val_loss: 0.0244
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0205 - val_loss: 0.0263
# Epoch 32/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0209 - val_loss: 0.0232
# Epoch 33/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0202 - val_loss: 0.0234
# Epoch 34/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0233
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0225
# Epoch 36/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 0.0229
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0197 - val_loss: 0.0235
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0197 - val_loss: 0.0223
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0204 - val_loss: 0.0241
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0209 - val_loss: 0.0230
# Epoch 41/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0236
# Epoch 42/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0194 - val_loss: 0.0226
# Epoch 43/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0244
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0195 - val_loss: 0.0233
# Epoch 45/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0202 - val_loss: 0.0262
# Epoch 46/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0192 - val_loss: 0.0239
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0194 - val_loss: 0.0237
# Epoch 48/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0248
# Epoch 49/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0191 - val_loss: 0.0236
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0235
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0225
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0262
# Epoch 53/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0200 - val_loss: 0.0237
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0194 - val_loss: 0.0239
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0193 - val_loss: 0.0241
# Epoch 56/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0189 - val_loss: 0.0233
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0193 - val_loss: 0.0249
# Epoch 58/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0200 - val_loss: 0.0236
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0254
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0191 - val_loss: 0.0236
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0238
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0247
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0190 - val_loss: 0.0250
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0246
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0189 - val_loss: 0.0259
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0194 - val_loss: 0.0240
# Epoch 67/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0191 - val_loss: 0.0245
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0247
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0253
# Epoch 70/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0253
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0265
# Epoch 72/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0195 - val_loss: 0.0251
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0232
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0306
# Epoch 75/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0193 - val_loss: 0.0267
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0198 - val_loss: 0.0247
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0243
# Epoch 78/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0245
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0189 - val_loss: 0.0241
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0242
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0303
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0203 - val_loss: 0.0297
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0198 - val_loss: 0.0233
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0246
# Epoch 85/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0253
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0237
# Epoch 87/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0235
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0180 - val_loss: 0.0250
# Epoch 89/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0249
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0239
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0240
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0283
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0256
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0234
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0252
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0238
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0234
# Epoch 98/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0187 - val_loss: 0.0240
# Epoch 99/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0267
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0179 - val_loss: 0.0233
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0248
# Pérdida en el conjunto de prueba: 0.024828612804412842
# 7/7 [==============================] - 0s 6ms/step

# %%
# Crear nuevos datos
nuevos_datos = pd.DataFrame({
    'Density': [4.5],
    'Tensile_Strength': [600],
    'Operating_Temp': [50]
})

# Escalar los nuevos datos
nuevos_datos_escalados = scaler_X.transform(nuevos_datos)

# Hacer la predicción
prediccion_escalada = model.predict(nuevos_datos_escalados)

# Reescalar la predicción a la escala original
prediccion_original = scaler_y.inverse_transform(prediccion_escalada)

print(f"Predicción del número de ciclos hasta la falla: {prediccion_original[0][0]}")
# Out:
# 1/1 [==============================] - 0s 46ms/step
# Predicción del número de ciclos hasta la falla: 53309.31640625
